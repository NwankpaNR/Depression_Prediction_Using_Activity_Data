# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, matthews_corrcoef, cohen_kappa_score
import matplotlib.pyplot as plt

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
combined_df = pd.read_csv('C:/Users/DELL G7/Pictures/Camera Roll/projects/newdepression/combined_data.csv')

# %%
combined_df.tail()
# Out:
#                    timestamp  activity     status        person
# 1571701  2002-06-28 09:40:00         0  depressed  condition_23
# 1571702  2002-06-28 09:41:00         0  depressed  condition_23
# 1571703  2002-06-28 09:42:00        48  depressed  condition_23
# 1571704  2002-06-28 09:43:00         0  depressed  condition_23
# 1571705  2002-06-28 09:44:00         0  depressed  condition_23

# %%
# Preprocessing: converting categorical labels to integer values
mapping = {'depressed': 1, 'nondepressed': 0}
combined_df['status'] = combined_df['status'].map(mapping)

# %%
combined_df.head()
# Out:
#              timestamp  activity  status     person
# 0  2003-03-18 15:00:00        60       0  control_1
# 1  2003-03-18 15:01:00         0       0  control_1
# 2  2003-03-18 15:02:00       264       0  control_1
# 3  2003-03-18 15:03:00       662       0  control_1
# 4  2003-03-18 15:04:00       293       0  control_1

# %%
# Create sequences

sequence_length = 24
sequences = []
labels = []
for person, group in combined_df.groupby('person'):
    for i in range(0, len(group) - sequence_length):
        sequences.append(group['activity'].iloc[i:i+sequence_length].values)
        labels.append(group['status'].iloc[i])

X = np.array(sequences)
y = np.array(labels)

# %%
nan_values_in_X = np.isnan(X)
print(f"Number of NaN values in X: {np.sum(nan_values_in_X)}")
# Out:
# Number of NaN values in X: 0

# %%
nan_values_in_y = np.isnan(y)
print(f"Number of NaN values in y: {np.sum(nan_values_in_y)}")
# Out:
# Number of NaN values in y: 0

# %%
# Convert data to PyTorch tensors


# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

X_train_tensor = torch.FloatTensor(X_train)
y_train_tensor = torch.LongTensor(y_train)
X_test_tensor = torch.FloatTensor(X_test)
y_test_tensor = torch.LongTensor(y_test)

# %%
# LSTM Model
class LSTMClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
        super(LSTMClassifier, self).__init__()
        self.hidden_dim = hidden_dim
        self.layer_dim = layer_dim
        self.rnn = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).requires_grad_().cuda()
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).requires_grad_().cuda()
        out, (hn, cn) = self.rnn(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :])
        return out

# %%
# Hyperparameters
input_dim = 1
hidden_dim = 100
layer_dim = 3
output_dim = 2
learning_rate = 0.001
num_epochs = 70
batch_size = 32  # Reduced batch size

# %%
model = LSTMClassifier(input_dim, hidden_dim, layer_dim, output_dim)
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
torch.cuda.empty_cache()

# %%
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

for epoch in range(num_epochs):
    train_loss = 0.0
    train_corrects = 0
    model.train()
    for i in range(0, len(X_train), batch_size):
        batch_X = X_train_tensor[i:i+batch_size].view(-1, sequence_length, 1).cuda()
        batch_y = y_train_tensor[i:i+batch_size].cuda()

        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        _, preds = torch.max(outputs, 1)
        train_corrects += torch.sum(preds == batch_y.data)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * batch_X.size(0)

    average_train_loss = train_loss / len(X_train)
    train_losses.append(average_train_loss)

    train_accuracy = train_corrects.double() / len(X_train)
    train_accuracies.append(train_accuracy.cpu().numpy())

    model.eval()
    test_loss = 0.0
    test_corrects = 0
    all_predictions = []
    with torch.no_grad():
        for i in range(0, len(X_test), batch_size):
            batch_X = X_test_tensor[i:i+batch_size].view(-1, sequence_length, 1).cuda()
            batch_y = y_test_tensor[i:i+batch_size].cuda()

            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            _, preds = torch.max(outputs, 1)
            all_predictions.extend(preds.cpu().numpy())
            test_corrects += torch.sum(preds == batch_y.data)

            test_loss += loss.item() * batch_X.size(0)

    average_test_loss = test_loss / len(X_test)
    test_losses.append(average_test_loss)

    test_accuracy = test_corrects.double() / len(X_test)
    test_accuracies.append(test_accuracy.cpu().numpy())
    
    print(f'Epoch {epoch+1}/{num_epochs}')
    print('-' * 10)
    print(f'Train Loss: {average_train_loss:.4f} Train Acc: {train_accuracy:.4f}')
    print(f'Test Loss: {average_test_loss:.4f} Test Acc: {test_accuracy:.4f}')
    print()
# Out:
# Epoch 1/70
# ----------
# Train Loss: 0.5930 Train Acc: 0.6807
# Test Loss: 0.5846 Test Acc: 0.6873
#
# Epoch 2/70
# ----------
# Train Loss: 0.5808 Train Acc: 0.6919
# Test Loss: 0.5828 Test Acc: 0.6899
#
# Epoch 3/70
# ----------
# Train Loss: 0.5758 Train Acc: 0.6963
# Test Loss: 0.5763 Test Acc: 0.6946
#
# Epoch 4/70
# ----------
# Train Loss: 0.5712 Train Acc: 0.7008
# Test Loss: 0.5706 Test Acc: 0.7006
#
# Epoch 5/70
# ----------
# Train Loss: 0.5646 Train Acc: 0.7066
# Test Loss: 0.5663 Test Acc: 0.7089
#
# Epoch 6/70
# ----------
# Train Loss: 0.5556 Train Acc: 0.7146
# Test Loss: 0.5527 Test Acc: 0.7154
#
# Epoch 7/70
# ----------
# Train Loss: 0.5436 Train Acc: 0.7237
# Test Loss: 0.5412 Test Acc: 0.7258
#
# Epoch 8/70
# ----------
# Train Loss: 0.5295 Train Acc: 0.7341
# Test Loss: 0.5283 Test Acc: 0.7352
#
# Epoch 9/70
# ----------
# Train Loss: 0.5157 Train Acc: 0.7430
# Test Loss: 0.5153 Test Acc: 0.7439
#
# Epoch 10/70
# ----------
# Train Loss: 0.5023 Train Acc: 0.7518
# Test Loss: 0.5066 Test Acc: 0.7499
#
# Epoch 11/70
# ----------
# Train Loss: 0.4904 Train Acc: 0.7593
# Test Loss: 0.4969 Test Acc: 0.7558
#
# Epoch 12/70
# ----------
# Train Loss: 0.4797 Train Acc: 0.7658
# Test Loss: 0.4869 Test Acc: 0.7624
#
# Epoch 13/70
# ----------
# Train Loss: 0.4693 Train Acc: 0.7724
# Test Loss: 0.4765 Test Acc: 0.7699
#
# Epoch 14/70
# ----------
# Train Loss: 0.4596 Train Acc: 0.7784
# Test Loss: 0.4730 Test Acc: 0.7711
#
# Epoch 15/70
# ----------
# Train Loss: 0.4508 Train Acc: 0.7834
# Test Loss: 0.4639 Test Acc: 0.7770
#
# Epoch 16/70
# ----------
# Train Loss: 0.4432 Train Acc: 0.7877
# Test Loss: 0.4574 Test Acc: 0.7809
#
# Epoch 17/70
# ----------
# Train Loss: 0.4366 Train Acc: 0.7917
# Test Loss: 0.4656 Test Acc: 0.7785
#
# Epoch 18/70
# ----------
# Train Loss: 0.4296 Train Acc: 0.7957
# Test Loss: 0.4501 Test Acc: 0.7854
#
# Epoch 19/70
# ----------
# Train Loss: 0.4235 Train Acc: 0.7992
# Test Loss: 0.4411 Test Acc: 0.7902
#
# Epoch 20/70
# ----------
# Train Loss: 0.4183 Train Acc: 0.8020
# Test Loss: 0.4417 Test Acc: 0.7899
#
# Epoch 21/70
# ----------
# Train Loss: 0.4131 Train Acc: 0.8047
# Test Loss: 0.4322 Test Acc: 0.7962
#
# Epoch 22/70
# ----------
# Train Loss: 0.4086 Train Acc: 0.8075
# Test Loss: 0.4299 Test Acc: 0.7972
#
# Epoch 23/70
# ----------
# Train Loss: 0.4051 Train Acc: 0.8097
# Test Loss: 0.4295 Test Acc: 0.7982
#
# Epoch 24/70
# ----------
# Train Loss: 0.4009 Train Acc: 0.8118
# Test Loss: 0.4343 Test Acc: 0.7959
#
# Epoch 25/70
# ----------
# Train Loss: 0.3981 Train Acc: 0.8135
# Test Loss: 0.4195 Test Acc: 0.8034
#
# Epoch 26/70
# ----------
# Train Loss: 0.3942 Train Acc: 0.8158
# Test Loss: 0.4183 Test Acc: 0.8039
#
# Epoch 27/70
# ----------
# Train Loss: 0.3909 Train Acc: 0.8174
# Test Loss: 0.4136 Test Acc: 0.8064
#
# Epoch 28/70
# ----------
# Train Loss: 0.3882 Train Acc: 0.8189
# Test Loss: 0.4087 Test Acc: 0.8090
#
# Epoch 29/70
# ----------
# Train Loss: 0.3858 Train Acc: 0.8204
# Test Loss: 0.4118 Test Acc: 0.8075
#
# Epoch 30/70
# ----------
# Train Loss: 0.3837 Train Acc: 0.8214
# Test Loss: 0.4113 Test Acc: 0.8086
#
# Epoch 31/70
# ----------
# Train Loss: 0.3807 Train Acc: 0.8230
# Test Loss: 0.4002 Test Acc: 0.8137
#
# Epoch 32/70
# ----------
# Train Loss: 0.3786 Train Acc: 0.8242
# Test Loss: 0.3995 Test Acc: 0.8139
#
# Epoch 33/70
# ----------
# Train Loss: 0.3764 Train Acc: 0.8253
# Test Loss: 0.4012 Test Acc: 0.8129
#
# Epoch 34/70
# ----------
# Train Loss: 0.3740 Train Acc: 0.8268
# Test Loss: 0.3946 Test Acc: 0.8162
#
# Epoch 35/70
# ----------
# Train Loss: 0.3722 Train Acc: 0.8277
# Test Loss: 0.3942 Test Acc: 0.8176
#
# Epoch 36/70
# ----------
# Train Loss: 0.3699 Train Acc: 0.8290
# Test Loss: 0.3915 Test Acc: 0.8190
#
# Epoch 37/70
# ----------
# Train Loss: 0.3684 Train Acc: 0.8300
# Test Loss: 0.3918 Test Acc: 0.8191
#
# Epoch 38/70
# ----------
# Train Loss: 0.3666 Train Acc: 0.8308
# Test Loss: 0.3997 Test Acc: 0.8152
#
# Epoch 39/70
# ----------
# Train Loss: 0.3651 Train Acc: 0.8316
# Test Loss: 0.3899 Test Acc: 0.8190
#
# Epoch 40/70
# ----------
# Train Loss: 0.3640 Train Acc: 0.8320
# Test Loss: 0.3915 Test Acc: 0.8196
#
# Epoch 41/70
# ----------
# Train Loss: 0.3613 Train Acc: 0.8335
# Test Loss: 0.3894 Test Acc: 0.8204
#
# Epoch 42/70
# ----------
# Train Loss: 0.3597 Train Acc: 0.8343
# Test Loss: 0.3899 Test Acc: 0.8205
#
# Epoch 43/70
# ----------
# Train Loss: 0.3585 Train Acc: 0.8355
# Test Loss: 0.3857 Test Acc: 0.8220
#
# Epoch 44/70
# ----------
# Train Loss: 0.3570 Train Acc: 0.8358
# Test Loss: 0.3810 Test Acc: 0.8242
#
# Epoch 45/70
# ----------
# Train Loss: 0.3555 Train Acc: 0.8368
# Test Loss: 0.3798 Test Acc: 0.8261
#
# Epoch 46/70
# ----------
# Train Loss: 0.3543 Train Acc: 0.8374
# Test Loss: 0.3780 Test Acc: 0.8253
#
# Epoch 47/70
# ----------
# Train Loss: 0.3536 Train Acc: 0.8381
# Test Loss: 0.3794 Test Acc: 0.8255
#
# Epoch 48/70
# ----------
# Train Loss: 0.3521 Train Acc: 0.8386
# Test Loss: 0.3754 Test Acc: 0.8276
#
# Epoch 49/70
# ----------
# Train Loss: 0.3502 Train Acc: 0.8397
# Test Loss: 0.3808 Test Acc: 0.8260
#
# Epoch 50/70
# ----------
# Train Loss: 0.3495 Train Acc: 0.8401
# Test Loss: 0.3818 Test Acc: 0.8255
#
# Epoch 51/70
# ----------
# Train Loss: 0.3488 Train Acc: 0.8404
# Test Loss: 0.3786 Test Acc: 0.8274
#
# Epoch 52/70
# ----------
# Train Loss: 0.3470 Train Acc: 0.8415
# Test Loss: 0.3779 Test Acc: 0.8276
#
# Epoch 53/70
# ----------
# Train Loss: 0.3465 Train Acc: 0.8418
# Test Loss: 0.3764 Test Acc: 0.8272
#
# Epoch 54/70
# ----------
# Train Loss: 0.3494 Train Acc: 0.8413
# Test Loss: 0.3859 Test Acc: 0.8245
#
# Epoch 55/70
# ----------
# Train Loss: 0.3552 Train Acc: 0.8386
# Test Loss: 0.3720 Test Acc: 0.8305
#
# Epoch 56/70
# ----------
# Train Loss: 0.3451 Train Acc: 0.8428
# Test Loss: 0.3696 Test Acc: 0.8315
#
# Epoch 57/70
# ----------
# Train Loss: 0.3434 Train Acc: 0.8434
# Test Loss: 0.3695 Test Acc: 0.8310
#
# Epoch 58/70
# ----------
# Train Loss: 0.3419 Train Acc: 0.8444
# Test Loss: 0.3691 Test Acc: 0.8310
#
# Epoch 59/70
# ----------
# Train Loss: 0.3415 Train Acc: 0.8447
# Test Loss: 0.3751 Test Acc: 0.8294
#
# Epoch 60/70
# ----------
# Train Loss: 0.3405 Train Acc: 0.8454
# Test Loss: 0.3654 Test Acc: 0.8331
#
# Epoch 61/70
# ----------
# Train Loss: 0.3399 Train Acc: 0.8455
# Test Loss: 0.3740 Test Acc: 0.8298
#
# Epoch 62/70
# ----------
# Train Loss: 0.3378 Train Acc: 0.8465
# Test Loss: 0.3684 Test Acc: 0.8328
#
# Epoch 63/70
# ----------
# Train Loss: 0.3384 Train Acc: 0.8462
# Test Loss: 0.3722 Test Acc: 0.8302
#
# Epoch 64/70
# ----------
# Train Loss: 0.3376 Train Acc: 0.8469
# Test Loss: 0.3691 Test Acc: 0.8325
#
# Epoch 65/70
# ----------
# Train Loss: 0.3359 Train Acc: 0.8474
# Test Loss: 0.3742 Test Acc: 0.8297
#
# Epoch 66/70
# ----------
# Train Loss: 0.3361 Train Acc: 0.8476
# Test Loss: 0.3720 Test Acc: 0.8309
#
# Epoch 67/70
# ----------
# Train Loss: 0.3346 Train Acc: 0.8483
# Test Loss: 0.3563 Test Acc: 0.8375
#
# Epoch 68/70
# ----------
# Train Loss: 0.3347 Train Acc: 0.8482
# Test Loss: 0.3627 Test Acc: 0.8355
#
# Epoch 69/70
# ----------
# Train Loss: 0.3329 Train Acc: 0.8489
# Test Loss: 0.3707 Test Acc: 0.8322
#
# Epoch 70/70
# ----------
# Train Loss: 0.3319 Train Acc: 0.8498
# Test Loss: 0.3608 Test Acc: 0.8368

# %%
# Save the model's state_dict
torch.save(model.state_dict(), 'C:/Users/DELL G7/Pictures/Camera Roll/projects/newdepression/lstm_70.pth')

# %%
# # Assuming the model class is named LSTMClassifier and is defined

# # Create a model object
# loaded_model = LSTMClassifier(input_dim=1, hidden_dim=100, output_dim=2, layer_dim=3)

# # Load the model's parameters from file
# loaded_model.load_state_dict(torch.load('C:/Users/DELL G7/Pictures/Camera Roll/projects/newdepression/lstm.pth'))

# # Set the model to evaluation mode (important for models with dropout layers, batch normalization, etc.)
# loaded_model.eval()

# %%
# Plotting
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.legend()
plt.title('Loss vs. Epochs')

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.legend()
plt.title('Accuracy vs. Epochs')
plt.show()

# %%
# Confusion Matrix Visualization
cm = confusion_matrix(y_test, all_predictions)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['NotDepressed', 'Depressed']
plt.title('Depression Detection Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(cm[i][j]))
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, all_predictions, target_names=classNames)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# NotDepressed       0.83      0.94      0.88    203845
#    Depressed       0.85      0.65      0.74    110233
#
#     accuracy                           0.84    314078
#    macro avg       0.84      0.79      0.81    314078
# weighted avg       0.84      0.84      0.83    314078

# %%
# ROC Curve
# ROC Curve
y_prob = nn.Softmax(dim=1)(outputs)

fpr, tpr, thresholds = roc_curve(y_test[-len(y_prob):], y_prob.cpu().detach().numpy()[:,1])
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# MCC and Cohen's Kappa
print("Matthews Correlation Coefficient:", matthews_corrcoef(y_test, all_predictions))
print("Cohen's Kappa:", cohen_kappa_score(y_test, all_predictions))
# Out:
# Matthews Correlation Coefficient: 0.6329046593338115
# Cohen's Kappa: 0.622172556339148
